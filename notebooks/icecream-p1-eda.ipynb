# %% [markdown]
# # Intro
#
# Dataset link: https://www.kaggle.com/datasets/tysonpo/ice-cream-dataset
#
# Inspiration Notebooks:
# - Using Ice Cream Ingredients to Predict Rating: https://www.kaggle.com/code/gcdatkin/using-ice-cream-ingredients-to-predict-rating
# - Finding the Best Ice Cream: https://www.kaggle.com/code/kelvintran1998/finding-the-best-ice-cream
# - EDA ideas: McDonalds Ice Cream Machines Breaking: https://www.kaggle.com/code/aashidutt3/eda-mcdonalds-ice-cream-machines-breaking

# %% [markdown]
# * Loading Data and Libraries

# %%
# loading libraries
import numpy as np
import pandas as pd
import os

# %%
# Get the parent directory of the notebook
notebook_dir = os.path.abspath('')  # This gets the current notebook path
project_root = os.path.dirname(notebook_dir)  # Go one level up if needed

# Change the working directory
os.chdir(project_root)

# %%
# reading dataset
df = pd.read_csv("data/input/raw-products.csv")
print("the dataset has " + str(df.shape[0]) + " observations (ice cream flavors) and " + str(df.shape[1]) + " features " + str([col for col in df.columns]))
# Out:
# the dataset has 241 observations (ice cream flavors) and 8 features ['brand', 'key', 'name', 'subhead', 'description', 'rating', 'rating_count', 'ingredients']

# %%
df.head(10)
# Out:
#   brand   key                           name  \
# 0    bj  0_bj            Salted Caramel Core
# 1    bj  1_bj            Netflix & Chilll'd™
# 2    bj  2_bj                   Chip Happens
# 3    bj  3_bj                        Cannoli
# 4    bj  4_bj                 Gimme S’more!™
# 5    bj  5_bj      Peanut Butter Half Baked®
# 6    bj  6_bj         Berry Sweet Mascarpone
# 7    bj  7_bj  Chocolate Peanut Butter Split
# 8    bj  8_bj              Justice ReMix'd ™
# 9    bj  9_bj          Boots on the Moooo’n™
#
#                                              subhead  \
# 0  Sweet Cream Ice Cream with Blonde Brownies & a...
# 1  Peanut Butter Ice Cream with Sweet & Salty Pre...
# 2  A Cold Mess of Chocolate Ice Cream with Fudge ...
# 3  Mascarpone Ice Cream with Fudge-Covered Pastry...
# 4  Toasted Marshmallow Ice Cream with Chocolate C...
# 5  Chocolate & Peanut Butter Ice Creams Mixed wit...
# 6  Blackberry & Mascarpone Ice Creams with Shortb...
# 7  Chocolate & Banana Ice Creams with Mini Peanut...
# 8  Cinnamon & Chocolate Ice Creams with Gobs of C...
# 9  A Universe of Milk Chocolate Ice Cream with Fu...
#
#                                          description  rating  rating_count  \
# 0  Find your way to the ultimate ice cream experi...     3.7           208
# 1  There’s something for everyone to watch on Net...     4.0           127
# 2  Sometimes “chip” happens and everything’s a me...     4.7           130
# 3  As a Limited Batch that captured the rapture o...     3.6            70
# 4  It’s a gimme: there’s always room for s’more. ...     4.5           281
# 5  If you were more than a little bit smitten wit...     4.9            14
# 6  From the sweet blackberry and crazy creamy mas...     4.6            10
# 7  We’ve loaded our banana and chocolate ice crea...     5.0             7
# 8  Now serving Justice ReMix’d: the flavor and ac...     4.3           110
# 9  While Space Force works to get boots (back) on...     4.7            42
#
#                                          ingredients
# 0  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 1  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 2  CREAM, LIQUID SUGAR (SUGAR, WATER), SKIM MILK,...
# 3  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 4  CREAM, SKIM MILK, WATER, LIQUID SUGAR (SUGAR, ...
# 5  CREAM, LIQUID SUGAR (SUGAR, WATER), SKIM MILK,...
# 6  CREAM, SKIM MILK, WATER, LIQUID SUGAR (SUGAR, ...
# 7  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 8  CREAM, LIQUID SUGAR (SUGAR, WATER), SKIM MILK,...
# 9  CREAM, LIQUID SUGAR (SUGAR, WATER), SKIM MILK,...

# %% [markdown]
# * Data Cleaning: transform brand feature to more readable names

# %%
# change brand name to be more readable

df['brand'] = df['brand'].replace(['hd','breyers','bj','talenti'],['HaagenDazs','Breyers','BenJerrys','Talenti'])
df['brand'].value_counts()
# Out:
# brand
# HaagenDazs    70
# Breyers       69
# BenJerrys     57
# Talenti       45
# Name: count, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# * Exploratory Data Analysis: Color Scheme

# %%
# loading dataviz libraries
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import rcParams

sns.set_theme(style="whitegrid")
sns.despine(left=True, bottom=True)

# %%
# color scheme
class clr:
    S = '\033[1m' + '\033[96m' # chance color text
    E = '\033[0m'
    
my_colors = ['#1F6082', '#6A2340', '#83563f', '#495057']

sns.palplot(sns.color_palette(my_colors))

print(clr.S + "Notebook Color Scheme: " + clr.E)
print(r"Ben Jerry's, Häagen-Dazs, Talenti, Breyers")
# Out:
# Notebook Color Scheme:
# Ben Jerry's, Häagen-Dazs, Talenti, Breyers

# %%
# create color reference dict
# the idea is to use this dict to sort the color code in the same way of the plot
color_reference = {'BenJerrys':'#1F6082', 'Breyers':'#495057', 'HaagenDazs':'#6A2340', 'Talenti':'#83563f'}
color_reference
# Out:
# {'BenJerrys': '#1F6082',
#  'Breyers': '#495057',
#  'HaagenDazs': '#6A2340',
#  'Talenti': '#83563f'}

# %%
# setting and standardizing parameters for all graphs
sns.set()
plt.style.use('seaborn-v0_8-notebook')
# %matplotlib inline
rcParams['figure.figsize'] = 12,8
rcParams['figure.titlesize'] = 14
rcParams['font.size'] = 15

# %% [markdown]
# * Exploratory Data Analysis

# %%
#getting flavors df
flavors = df['brand'].value_counts().reset_index().sort_values('count', ascending=False)
flavors
# Out:
#         brand  count
# 0  HaagenDazs     70
# 1     Breyers     69
# 2   BenJerrys     57
# 3     Talenti     45

# %%
# plot the brands flavors counts
plt.figure(figsize=(6, 4))
colors = flavors['brand'].replace(color_reference) # replace elements in a list using dictionary lookup
colors = colors.tolist() # list of colors for palette parameter in sns plot
splot = sns.barplot(data=flavors, x='brand', y='count', palette=colors, hue='brand')
plt.ylim([0,80])
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.xlabel('Brand', fontsize=14)
plt.ylabel('# Flavors', fontsize=14)
# Out:
# Text(0, 0.5, '# Flavors')

# %% [markdown]
# * Exploratory Data Analysis: Flavors vs Rating

# %%
# rating distribution
plt.figure(figsize=(6, 4))
sns.histplot(data=df, x='rating', hue='brand', multiple='stack')
plt.xlim([0,5.0])
plt.xticks(np.arange(0,5.1, step=0.5))
plt.xlabel('Average Rating', fontsize=14)
plt.ylabel('Flavors', fontsize=14)
# Out:
# Text(0, 0.5, 'Flavors')

# %% [markdown]
# Calculating kurtosis and Skewness

# %%
# import scipy
from scipy.stats import skew, kurtosis

# %%
# calculate the skewness
skewness = skew(df['rating'], axis=0)
if skewness == 0:
    print('the skewness value is ' + str(round(skewness,2)) + '. Then normally distributed.')
if skewness > 0:
    print('the skewness value is ' + str(round(skewness,2)) + '. Then more weight in the left tail of the distribution.')
if skewness < 0:
    print('the skewness value is ' + str(round(skewness,2)) + '. Then more weight in the right tail of the distribution.')
# Out:
# the skewness value is -1.56. Then more weight in the right tail of the distribution.

# %%
# calculate the kurtosis
kurt =  kurtosis(df['rating'], axis=0)
if kurt == 3:
    print('the skewness value is ' + str(round(kurt,2)) + '. Then the distribution is mesokurtic.')
if kurt < 3:
    print('the skewness value is ' + str(round(kurt,2)) + '. Then the distribution is platykurtic (short tails).')
if kurt > 3:
    print('the skewness value is ' + str(round(kurt,2)) + '. Then the distribution is leptokurtic (thinner in the center and fatter tails. ie more outliers)')
# Out:
# the skewness value is 3.03. Then the distribution is leptokurtic (thinner in the center and fatter tails. ie more outliers)

# %%
# change column names
ratings_by_brand = df.groupby('brand')['rating_count'].sum().reset_index().sort_values('brand', ascending=True)
ratings_by_brand
# Out:
#         brand  rating_count
# 0   BenJerrys          7954
# 1     Breyers          5009
# 2  HaagenDazs          4657
# 3     Talenti          4074

# %%
# plot the brands flavors counts
plt.figure(figsize=(6, 4))
colors = ratings_by_brand['brand'].replace(color_reference) # replace elements in a list using dictionary lookup
colors = colors.tolist() # list of colors for palette parameter in sns plot
splot = sns.barplot(data=ratings_by_brand, x='brand', y='rating_count', palette=colors, hue='brand')
plt.ylim([0,9000])
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.xlabel('Brand', size=14)
plt.ylabel('# Reviews', size=14)
# Out:
# Text(0, 0.5, '# Reviews')

# %%
# scatter plot by brand
sns.relplot(data=df,
                x='rating', y='rating_count',
                hue='brand',
                col='brand',
                palette=my_colors,
                sizes=(1, 6), linewidth=0, col_wrap=2
                )

# %%
# scatter plot by rating vs. brand
_, axs = plt.subplots(nrows=1, ncols=2) # making a subplot with 1 row and 2 columns
sns.stripplot(data=df, x='brand', y='rating', palette=my_colors, ax=axs[0], hue='brand')
sns.boxplot(data=df, x='brand', y='rating', palette=my_colors, ax=axs[1], hue='brand')
# Out:
# <Axes: xlabel='brand', ylabel='rating'>

# %% [markdown]
# * Excluding Flavors with low number of rating

# %%
# filtering underepresented groups to prevent bias
low_rating_count = df.query('rating_count < 10') # number choosed arbritrary
low_rating_count
# Out:
#           brand         key                               name  \
# 7     BenJerrys        7_bj      Chocolate Peanut Butter Split
# 11    BenJerrys       11_bj                  Bourbon Pecan Pie
# 62   HaagenDazs        5_hd  Caramel Soft Dipped Ice Cream Bar
# 101  HaagenDazs       44_hd      Peppermint Bark Ice Cream Bar
# 213     Breyers  41_breyers              OREO® Snack Cups 10ct
#
#                                                subhead  \
# 7    Chocolate & Banana Ice Creams with Mini Peanut...
# 11   Buttery Bourbon Ice Cream with Pecans, Shortbr...
# 62                                                 NaN
# 101                                                NaN
# 213                                                NaN
#
#                                            description  rating  rating_count  \
# 7    We’ve loaded our banana and chocolate ice crea...     5.0             7
# 11   Not long ago we scoop-toured through Texas ask...     4.6             9
# 62   Introducing New Soft Dipped Caramel Ice Cream ...     4.9             8
# 101  Our peppermint bark ice cream bars start with ...     5.0             8
# 213  Breyers® vanilla with real OREO®? Yes please! ...     5.0             2
#
#                                            ingredients
# 7    CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 11   CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 62   CARAMEL ICE CREAM: CREAM, SKIM MILK, SUGAR, EG...
# 101  WHITE CHOCOLATE ICE CREAM: CREAM, SKIM MILK, S...
# 213  SKIM MILK, LIQUID SUGAR, SUGAR, WATER, CREAM, ...

# %% [markdown]
# * Checking the worst rated ice creams with their reviews

# %%
worst10 = df.sort_values('rating').head(10)
worst10
# Out:
#           brand         key                                         name  \
# 221     Breyers  49_breyers                  Chocolate Chip Cookie Dough
# 50    BenJerrys       50_bj             Chocolate Chip Cookie Dough Core
# 223     Breyers  51_breyers                                       Coffee
# 123  HaagenDazs       66_hd  Vanilla Milk Chocolate Almond Ice Cream Bar
# 238     Breyers  66_breyers                      Layered Dessert S'mores
# 210     Breyers  38_breyers                                 Butter Pecan
# 67   HaagenDazs       10_hd          Chocolate Soft Dipped Ice Cream Bar
# 97   HaagenDazs       40_hd    Peanut Butter Chip HEAVEN Light Ice Cream
# 240     Breyers  68_breyers           Layered Dessert Brownie Cheesecake
# 195     Breyers  23_breyers                     CarbSmart™ Peanut Butter
#
#                                                subhead  \
# 221                                                NaN
# 50   Cookie Milk Ice Cream with Fudge Chips & a Cho...
# 223                                                NaN
# 123                                                NaN
# 238                                                NaN
# 210                                                NaN
# 67                                                 NaN
# 97                                                 NaN
# 240                                                NaN
# 195                                                NaN
#
#                                            description  rating  rating_count  \
# 221  With creamy vanilla and chunks of cookie dough...     1.2            89
# 50   Our latest cookie dough creation is boldly loa...     1.8           166
# 223  Enjoy Breyers® Coffee by the scoop and brew up...     2.4            52
# 123  We start with pure, sweet vanilla and blend it...     2.5           224
# 238  Calling all S'mores lovers! Make sure you don'...     2.5            31
# 210  Discover Breyers® Butter Pecan with rich vanil...     2.6            74
# 67   Introducing New Soft Dipped Chocolate Ice Crea...     2.6            25
# 97   Introducing new HEAVEN Peanut Butter Chip ligh...     2.7            25
# 240  Love brownie cheesecake? What about Breyers®? ...     2.8            25
# 195  Breyers® CarbSmart™ proves that fewer carbs do...     2.8            88
#
#                                            ingredients
# 221  MILK, SUGAR, CORN SYRUP, CREAM, ENRICHED WHEAT...
# 50   CREAM, SKIM MILK, WATER, LIQUID SUGAR (SUGAR, ...
# 223  MILK, CORN SYRUP, SUGAR, CREAM, COFFEE EXTRACT...
# 123  CREAM, SKIM MILK, SUGAR, EGG YOLKS, MILK CHOCO...
# 238  MILK, CORN SYRUP, SUGAR, WHEAT FLOUR, BUTTER, ...
# 210  MILK, SUGAR, CORN SYRUP, CREAM, PECANS, WHEY, ...
# 67   CHOCOLATE ICE CREAM: CREAM, SKIM MILK, SUGAR, ...
# 97   SKIM MILK, CREAM, CANE SUGAR, PEANUTS, EGG YOL...
# 240  MILK, CORN SYRUP, SUGAR, ENRICHED WHEAT FLOUR,...
# 195  MILK, CREAM, SORBITOL, MALTODEXTRIN (CORN), PE...

# %%
# calling the ice cream reviews dataset
df_reviews = pd.read_csv("data/input/raw-reviews.csv")

# %%
# create a list of values to filter by ice cream's keys
values_list = worst10['key'].unique()

# filtering by two conditions: ice creams worst ratings and one star reviews
filtered_reviews = df_reviews[df_reviews['key'].isin(values_list)]
worst10_1star_reviews =  filtered_reviews.query('stars == 1') # getting one starred reviews for the 

# cleaning the worst10_1star_reviews df to become more readable
worst10_1star_reviews.loc[:, 'brand'] = worst10_1star_reviews['brand'].replace(
    ['hd','breyers','bj','talenti'],
    ['HaagenDazs','Breyers','BenJerrys','Talenti']
    )
worst10_1star_reviews = worst10_1star_reviews.drop(columns=
                                                   ['key','author', 'date', 'taste', 'ingredients', 'texture', 'likes', 'helpful_yes', 'helpful_no'])
worst10_1star_reviews
# Out:
#            brand  stars                                       title  \
# 7308   BenJerrys      1  Tiniest amount of cookie dough of all time
# 7310   BenJerrys      1                             Is this a joke?
# 7311   BenJerrys      1                          wish it was better
# 7312   BenJerrys      1                                Heartbreaker
# 7313   BenJerrys      1                                Disappointed
# ...          ...    ...                                         ...
# 21663    Breyers      1                                  Flavorless
# 21664    Breyers      1                                         NaN
# 21666    Breyers      1                           very disappointed
# 21669    Breyers      1    Terrible missing the chocolate ice cream
# 21670    Breyers      1                                    Terrible
#
#                                                     text
# 7308   I love Ben & Jerry’s which is why I am writing...
# 7310   I was so excited for this because I love cooki...
# 7311   Even after reading all the reviews that said i...
# 7312   I preordered this as soon as they announced th...
# 7313   I waited and waited for this to be available a...
# ...                                                  ...
# 21663  I was really looking forward to ice cream unfo...
# 21664  It wasn't as good as I thought it was going to...
# 21666  I gave never been this disappointed in an ice ...
# 21669  There was no chocolate ice cream in this at al...
# 21670  This ice cream has no flavor at all. No one in...
#
# [412 rows x 4 columns]

# %% [markdown]
# * Data Cleaning: dropping unused columns

# %%
# we don't need to use these columns for future analysis, so we will drop it
df = df.drop(columns=['key','subhead','description'])

# %%
worst10_reviews = worst10.drop(columns=['key','subhead','ingredients'])
worst10_reviews
# Out:
#           brand                                         name  \
# 221     Breyers                  Chocolate Chip Cookie Dough
# 50    BenJerrys             Chocolate Chip Cookie Dough Core
# 223     Breyers                                       Coffee
# 123  HaagenDazs  Vanilla Milk Chocolate Almond Ice Cream Bar
# 238     Breyers                      Layered Dessert S'mores
# 210     Breyers                                 Butter Pecan
# 67   HaagenDazs          Chocolate Soft Dipped Ice Cream Bar
# 97   HaagenDazs    Peanut Butter Chip HEAVEN Light Ice Cream
# 240     Breyers           Layered Dessert Brownie Cheesecake
# 195     Breyers                     CarbSmart™ Peanut Butter
#
#                                            description  rating  rating_count
# 221  With creamy vanilla and chunks of cookie dough...     1.2            89
# 50   Our latest cookie dough creation is boldly loa...     1.8           166
# 223  Enjoy Breyers® Coffee by the scoop and brew up...     2.4            52
# 123  We start with pure, sweet vanilla and blend it...     2.5           224
# 238  Calling all S'mores lovers! Make sure you don'...     2.5            31
# 210  Discover Breyers® Butter Pecan with rich vanil...     2.6            74
# 67   Introducing New Soft Dipped Chocolate Ice Crea...     2.6            25
# 97   Introducing new HEAVEN Peanut Butter Chip ligh...     2.7            25
# 240  Love brownie cheesecake? What about Breyers®? ...     2.8            25
# 195  Breyers® CarbSmart™ proves that fewer carbs do...     2.8            88

# %% [markdown]
# * Top Ice Cream for each brand

# %%
# top 10 Ben & Jerry's ice creams
top10_bj = df[df['brand'] == 'BenJerrys'].sort_values(by=['rating','rating_count'], ascending=False).head(10)
top10_bj
# Out:
#         brand                                name  rating  rating_count  \
# 29  BenJerrys                    Ice Cream Sammie     5.0            31
# 7   BenJerrys       Chocolate Peanut Butter Split     5.0             7
# 36  BenJerrys                Peanut Butter World®     4.9            69
# 33  BenJerrys         New York Super Fudge Chunk®     4.9            63
# 23  BenJerrys        Coffee Coffee BuzzBuzzBuzz!®     4.9            47
# 5   BenJerrys           Peanut Butter Half Baked®     4.9            14
# 51  BenJerrys  Sweet Like Sugar Cookie Dough Core     4.8           123
# 37  BenJerrys                         Phish Food®     4.8            93
# 19  BenJerrys                  Chocolate Therapy®     4.8            72
# 48  BenJerrys               Vanilla Caramel Fudge     4.8            29
#
#                                           ingredients
# 29  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 7   CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 36  CREAM, LIQUID SUGAR (SUGAR, WATER), SKIM MILK,...
# 33  CREAM, LIQUID SUGAR (SUGAR, WATER), SKIM MILK,...
# 23  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 5   CREAM, LIQUID SUGAR (SUGAR, WATER), SKIM MILK,...
# 51  CREAM, SKIM MILK, WATER, LIQUID SUGAR (SUGAR, ...
# 37  CREAM, WATER, SKIM MILK, LIQUID SUGAR (SUGAR, ...
# 19  CREAM, LIQUID SUGAR (SUGAR, WATER), SKIM MILK,...
# 48  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...

# %%
# top 10 Haagen Dazs ice creams
top10_hd = df[df['brand'] == 'HaagenDazs'].sort_values(by=['rating','rating_count'], ascending=False).head(10)
top10_hd
# Out:
#           brand                                               name  rating  \
# 88   HaagenDazs              Honey Salted Caramel Almond Ice Cream     5.0
# 120  HaagenDazs  Vanilla Caramel White Chocolate TRIO CRISPY LA...     5.0
# 100  HaagenDazs                          Peppermint Bark Ice Cream     5.0
# 71   HaagenDazs                      Chocolate Fudge Non-Dairy Bar     5.0
# 101  HaagenDazs                      Peppermint Bark Ice Cream Bar     5.0
# 57   HaagenDazs        White Chocolate Raspberry Truffle Ice Cream     4.9
# 66   HaagenDazs                                Chocolate Ice Cream     4.9
# 89   HaagenDazs                         Irish Cream Cookie Squares     4.9
# 75   HaagenDazs                          Coconut Caramel Non-Dairy     4.9
# 62   HaagenDazs                  Caramel Soft Dipped Ice Cream Bar     4.9
#
#      rating_count                                        ingredients
# 88            103  CREAM, SKIM MILK, SUGAR, SWEETENED CONDENSED M...
# 120            32  CREAM, SKIM MILK, SUGAR, SWEETENED CONDENSED M...
# 100            31  WHITE CHOCOLATE ICE CREAM (CREAM, SKIM MILK, S...
# 71             22  WATER, SUGAR, CORN SYRUP, CHOCOLATE, COCONUT O...
# 101             8  WHITE CHOCOLATE ICE CREAM: CREAM, SKIM MILK, S...
# 57            168  CREAM, SKIM MILK, SUGAR, RASPBERRY PUREE, LACT...
# 66             90  CREAM, SKIM MILK, CANE SUGAR, COCOA PROCESSED ...
# 89             14  CREAM, SKIM MILK, SUGAR, CORN SYRUP, EGG YOLKS...
# 75             11  COCONUT CREAM (COCONUT EXTRACT, WATER), CORN S...
# 62              8  CARAMEL ICE CREAM: CREAM, SKIM MILK, SUGAR, EG...

# %%
# top 10 Talenti ice creams
top10_tl = df[df['brand'] == 'Talenti'].sort_values(by=['rating','rating_count'], ascending=False).head(10)
top10_tl
# Out:
#        brand                             name  rating  rating_count  \
# 132  Talenti         CARAMEL APPLE PIE GELATO     4.8           115
# 138  Talenti  COCONUT ALMOND CHOCOLATE GELATO     4.8            82
# 129  Talenti         BELGIAN CHOCOLATE GELATO     4.8            27
# 157  Talenti  ORGANIC OAK-AGED VANILLA GELATO     4.8            19
# 151  Talenti        MEDITERRANEAN MINT GELATO     4.7           324
# 164  Talenti         ROMAN RASPBERRY SORBETTO     4.7           161
# 165  Talenti           SALTED CARAMEL TRUFFLE     4.7           160
# 127  Talenti          ALPHONSO MANGO SORBETTO     4.7           139
# 159  Talenti     PEANUT BUTTER FUDGE SORBETTO     4.7            77
# 152  Talenti                MINT FUDGE COOKIE     4.7            52
#
#                                            ingredients
# 132  MILK, SUGAR, CREAM, DEXTROSE, SKIM MILK, WHEAT...
# 138  MILK, SUGAR, CREAM, CHOCOLATE (PROCESSED WITH ...
# 129  MILK, SUGAR, CREAM, EGG AND EGG YOLK, DEXTROSE...
# 157  INGREDIENTS: ORGANIC SKIM MILK, ORGANIC CREAM,...
# 151  MILK, SUGAR, CREAM, CHOCOLATE, DEXTROSE, MILK ...
# 164  RASPBERRIES, WATER, SUGAR, DEXTROSE, LEMON JUI...
# 165  MILK, SUGAR, SKIM MILK, CREAM, WATER, COCONUT ...
# 127  MANGOS, WATER, SUGAR, DEXTROSE, LEMON JUICE, C...
# 159  WATER, PEANUTS, SUGAR, DEXTROSE, SALT, COCOA P...
# 152  MILK, SUGAR, CREAM, COCONUT OIL, WHEAT FLOUR, ...

# %%
# top 10 Breyers ice creams
top10_br = df[df['brand'] == 'Breyers'].sort_values(by=['rating','rating_count'], ascending=False).head(10)
top10_br
# Out:
#        brand                             name  rating  rating_count  \
# 213  Breyers            OREO® Snack Cups 10ct     5.0             2
# 235  Breyers        Chocolate Snack Cups 10ct     4.9            26
# 202  Breyers     No Sugar Added Caramel Swirl     4.9            19
# 198  Breyers  Non-Dairy Vanilla Peanut Butter     4.8           116
# 175  Breyers                        Chocolate     4.7           225
# 196  Breyers           Lactose Free Chocolate     4.7            24
# 237  Breyers     CarbSmart™ Caramel Swirl Bar     4.7            18
# 224  Breyers                Vanilla Chocolate     4.6            95
# 233  Breyers  Natural Vanilla Snack Cups 10ct     4.6            28
# 212  Breyers        CarbSmart™ Mint Fudge Bar     4.6            20
#
#                                            ingredients
# 213  SKIM MILK, LIQUID SUGAR, SUGAR, WATER, CREAM, ...
# 235  MILK, CREAM, SUGAR, WATER, DUTCHED COCOA (PROC...
# 202  MILK, MALTITOL SYRUP, MALTODEXTRIN (CORN), CRE...
# 198  ALMOND MILK, WATER, ALMONDS, LIQUID SUGAR, SUG...
# 175  MILK, CREAM, SUGAR, DUTCHED COCOA (PROCESSED W...
# 196  SKIM MILK, SUGAR, CORN SYRUP, CREAM, DUTCHED C...
# 237  MILK, WATER, CARAMEL SWIRL, SUGAR, WATER, CORN...
# 224  MILK, CREAM, SUGAR, WHEY, DUTCHED COCOA (PROCE...
# 233  MILK, CREAM, SUGAR, WATER, VEGETABLE GUM (TARA...
# 212  MILK, WATER, FUDGE SWIRL, CORN SYRUP, HIGH FRU...

# %% [markdown]
# * Bottom Ice Cream for each brand

# %%
# bottom 10 Ben & Jerry's ice creams
bot10_bj = df[df['brand'] == 'BenJerrys'].sort_values(by=['rating','rating_count'], ascending=False).tail(10)
bot10_bj
# Out:
#         brand                                  name  rating  rating_count  \
# 26  BenJerrys                Everything But The...®     3.8            72
# 0   BenJerrys                   Salted Caramel Core     3.7           208
# 3   BenJerrys                               Cannoli     3.6            70
# 53  BenJerrys                   Brownie Batter Core     3.5           108
# 17  BenJerrys               Chocolate Fudge Brownie     3.4           204
# 40  BenJerrys                Red, White & Blueberry     3.4            39
# 15  BenJerrys                   Chillin' the Roast™     3.3           172
# 52  BenJerrys  Wake & " No Bake " Cookie Dough Core     3.3            68
# 24  BenJerrys              Coffee Toffee Bar Crunch     2.9           302
# 50  BenJerrys      Chocolate Chip Cookie Dough Core     1.8           166
#
#                                           ingredients
# 26  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 0   CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 3   CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 53  CREAM, LIQUID SUGAR (SUGAR, WATER), SKIM MILK,...
# 17  CREAM, LIQUID SUGAR (SUGAR, WATER), SKIM MILK,...
# 40  CREAM, SKIM MILK, WATER, LIQUID SUGAR (SUGAR, ...
# 15  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 52  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 24  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 50  CREAM, SKIM MILK, WATER, LIQUID SUGAR (SUGAR, ...

# %%
# bottom 10 Haagen Dazs ice creams
bot10_hd = df[df['brand'] == 'HaagenDazs'].sort_values(by=['rating','rating_count'], ascending=False).tail(10)
bot10_hd
# Out:
#           brand                                         name  rating  \
# 109  HaagenDazs                         Rum Raisin Ice Cream     3.5
# 107  HaagenDazs                     Ruby Cacao Ice Cream Bar     3.5
# 111  HaagenDazs  Salted Caramel Chocolate TRIO CRISPY LAYERS     3.4
# 95   HaagenDazs                          Mint Chip Ice Cream     3.4
# 68   HaagenDazs        Chocolate Chip Cookie Dough Ice Cream     3.3
# 80   HaagenDazs                        Coffee Chip Ice Cream     3.1
# 116  HaagenDazs                            Vanilla Ice Cream     3.0
# 97   HaagenDazs    Peanut Butter Chip HEAVEN Light Ice Cream     2.7
# 67   HaagenDazs          Chocolate Soft Dipped Ice Cream Bar     2.6
# 123  HaagenDazs  Vanilla Milk Chocolate Almond Ice Cream Bar     2.5
#
#      rating_count                                        ingredients
# 109           129  CREAM, SKIM MILK, CANE SUGAR, RAISINS, EGG YOL...
# 107            31  CREAM, SKIM MILK, SUGAR, COCOA BUTTER, WHOLE M...
# 111            55  CREAM, SKIM MILK, CANE SUGAR, COCOA PROCESSED ...
# 95             35  CREAM, SKIM MILK, SUGAR, LACTOSE REDUCED SKIM ...
# 68             29  CREAM, SKIM MILK, SUGAR, WHEAT FLOUR, BROWN SU...
# 80            111  CREAM, SKIM MILK, SUGAR, POWDERED SUGAR, SUGAR...
# 116           228  CREAM, SKIM MILK, CANE SUGAR, EGG YOLKS, VANIL...
# 97             25  SKIM MILK, CREAM, CANE SUGAR, PEANUTS, EGG YOL...
# 67             25  CHOCOLATE ICE CREAM: CREAM, SKIM MILK, SUGAR, ...
# 123           224  CREAM, SKIM MILK, SUGAR, EGG YOLKS, MILK CHOCO...

# %%
# bottom 10 Talenti ice creams
bot10_tl = df[df['brand'] == 'Talenti'].sort_values(by=['rating','rating_count'], ascending=False).tail(10)
bot10_tl
# Out:
#        brand                                   name  rating  rating_count  \
# 149  Talenti                        LEMON BERRY PIE     4.2            31
# 128  Talenti                  BANANA CARAMEL CRUNCH     4.2            25
# 166  Talenti                SEA SALT CARAMEL GELATO     4.1           146
# 130  Talenti  BLACK RASPBERRY CHOCOLATE CHIP GELATO     4.0           105
# 150  Talenti         MADAGASCAN VANILLA BEAN GELATO     3.9           198
# 163  Talenti            RASPBERRY CHEESECAKE GELATO     3.9            76
# 169  Talenti       VANILLA BLUEBERRY CRUMBLE GELATO     3.9            70
# 148  Talenti                    KEY LIME PIE GELATO     3.6           208
# 170  Talenti           VANILLA CARAMEL SWIRL GELATO     3.6            38
# 136  Talenti     CHOCOLATE CHIP COOKIE DOUGH GELATO     2.8           104
#
#                                            ingredients
# 149  MILK, SUGAR†, CREAM, LEMON JUICE, WHEAT FLOUR,...
# 128  MILK, BANANAS, SUGAR†, WHEAT FLOUR, CREAM, NON...
# 166  MILK, SKIM MILK, SUGAR, CREAM, EGG YOLK AND WH...
# 130  MILK, SUGAR, CREAM, BLACK RASPBERRIES, DEXTROS...
# 150  MILK, SUGAR, CREAM, DEXTROSE, VANILLA EXTRACT,...
# 163  MILK, SUGAR, CREAM, CREAM CHEESE (MILK, CREAM,...
# 169  MILK, SUGAR, CREAM, TAPIOCA SYRUP, DEXTROSE, R...
# 148  MILK, SUGAR, CREAM, DEXTROSE, WHEAT FLOUR, COT...
# 170  MILK, SUGAR, CREAM, SKIM MILK, DEXTROSE, VANIL...
# 136  MILK, SUGAR, CREAM, WHEAT FLOUR, DEXTROSE, SKI...

# %%
# bottom 10 Breyers ice creams
bot10_br = df[df['brand'] == 'Breyers'].sort_values(by=['rating','rating_count'], ascending=False).tail(10)
bot10_br
# Out:
#        brand                                name  rating  rating_count  \
# 226  Breyers              Extra Creamy Chocolate     3.1            13
# 192  Breyers                               Peach     3.0            49
# 218  Breyers                          Rocky Road     3.0            42
# 219  Breyers                      Cherry Vanilla     3.0            40
# 195  Breyers            CarbSmart™ Peanut Butter     2.8            88
# 240  Breyers  Layered Dessert Brownie Cheesecake     2.8            25
# 210  Breyers                        Butter Pecan     2.6            74
# 238  Breyers             Layered Dessert S'mores     2.5            31
# 223  Breyers                              Coffee     2.4            52
# 221  Breyers         Chocolate Chip Cookie Dough     1.2            89
#
#                                            ingredients
# 226  MILK, SUGAR, CORN SYRUP, CREAM, DUTCHED COCOA ...
# 192  MILK, PEACHES, SUGAR, CORN SYRUP, CREAM, WHEY,...
# 218  SKIM MILK, CORN SYRUP, WATER, SUGAR, FRUCTOSE,...
# 219  MILK, SUGAR, CORN SYRUP, CHERRIES, CREAM, WHEY...
# 195  MILK, CREAM, SORBITOL, MALTODEXTRIN (CORN), PE...
# 240  MILK, CORN SYRUP, SUGAR, ENRICHED WHEAT FLOUR,...
# 210  MILK, SUGAR, CORN SYRUP, CREAM, PECANS, WHEY, ...
# 238  MILK, CORN SYRUP, SUGAR, WHEAT FLOUR, BUTTER, ...
# 223  MILK, CORN SYRUP, SUGAR, CREAM, COFFEE EXTRACT...
# 221  MILK, SUGAR, CORN SYRUP, CREAM, ENRICHED WHEAT...

# %% [markdown]
# * Top10 and Bot10 Comparison Table

# %%
# creating a table to compare the average score with the average top10 score for each brand
grouped = df.groupby('brand')['rating'].mean().round(2)
new_column_rating_count = df.groupby('brand')['rating_count'].sum()
grouped = pd.concat([grouped, new_column_rating_count], axis=1).rename(columns={'rating':'rating_avg'})
grouped
# Out:
#             rating_avg  rating_count
# brand
# BenJerrys         4.33          7954
# Breyers           3.96          5009
# HaagenDazs        4.31          4657
# Talenti           4.36          4074

# %%
# calculating and inserting the top10 values to the table:
top10grouped = grouped.copy()
brand_dict = {'BenJerrys': top10_bj, 'Breyers': top10_br, 'HaagenDazs': top10_hd, 'Talenti': top10_tl}

for brand, top10_df in brand_dict.items():
    grouped_mean = top10_df.groupby('brand')['rating'].mean()
    grouped_count = top10_df.groupby('brand')['rating_count'].sum()
    grouped_top10 = pd.concat([grouped_mean, grouped_count], axis=1)
    grouped_top10 = grouped_top10.rename(columns={'rating': 'top10_rating_avg', 'rating_count': 'top10_count'})

    # inserting these values into the table generated on the previous step:
    top10grouped.loc[brand, 'top10_rating_avg'] = grouped_top10['top10_rating_avg'].iloc[0]
    top10grouped.loc[brand, 'top10_count'] = grouped_top10['top10_count'].iloc[0]

top10grouped['top10_count'] = top10grouped['top10_count'].astype(int)
top10grouped
# Out:
#             rating_avg  rating_count  top10_rating_avg  top10_count
# brand
# BenJerrys         4.33          7954              4.88          548
# Breyers           3.96          5009              4.75          573
# HaagenDazs        4.31          4657              4.95          487
# Talenti           4.36          4074              4.74         1156

# %%
grouped
# Out:
#             rating_avg  rating_count
# brand
# BenJerrys         4.33          7954
# Breyers           3.96          5009
# HaagenDazs        4.31          4657
# Talenti           4.36          4074

# %% [markdown]
# * Bottom10 Comparison Table

# %%
# calculating and inserting the bot10 values to the table:
bot10grouped = grouped.copy()
brand_dict = {'BenJerrys': bot10_bj, 'Breyers': bot10_br, 'HaagenDazs': bot10_hd, 'Talenti': bot10_tl}

for brand, bot10_df in brand_dict.items():
    grouped_mean = bot10_df.groupby('brand')['rating'].mean()
    grouped_count = bot10_df.groupby('brand')['rating_count'].sum()
    grouped_bot10 = pd.concat([grouped_mean, grouped_count], axis=1)
    grouped_bot10 = grouped_bot10.rename(columns={'rating': 'bot10_rating_avg', 'rating_count':'bot10_count'})

    # inserting these values into the table generated on the previous step:
    bot10grouped.loc[brand, 'bot10_rating_avg'] = grouped_bot10['bot10_rating_avg'].iloc[0]
    bot10grouped.loc[brand, 'bot10_count'] = grouped_bot10['bot10_count'].iloc[0]

bot10grouped['bot10_count'] = bot10grouped['bot10_count'].astype(int)
bot10grouped
# Out:
#             rating_avg  rating_count  bot10_rating_avg  bot10_count
# brand
# BenJerrys         4.33          7954              3.27         1409
# Breyers           3.96          5009              2.64          503
# HaagenDazs        4.31          4657              3.10          892
# Talenti           4.36          4074              3.82         1001

# %% [markdown]
# # Saving the Results in csv Files

# %% [markdown]
# * Creating gist csv files for the medium articles

# %%
eda_path = os.path.join(project_root, 'data', 'eda\\')
df.head().to_csv(eda_path + 'icecream_head.csv', index=False, header=True, encoding='cp1252')
df.tail().to_csv(eda_path + 'icecream_tail.csv', index=False, header=True, encoding='cp1252')
low_rating_count.to_csv(eda_path + 'icecream_low_rating_count.csv', index=False, header=True, encoding='cp1252')
worst10.to_csv(eda_path + 'icecream_worst_flavors.csv', index=False, header=True, encoding='cp1252')
worst10_1star_reviews.to_csv(eda_path + 'icecream_worst10_1star_reviews.csv', index=False, header=True, encoding='utf-8')
worst10_reviews.to_csv(eda_path + 'icecream_worst10_negative_reviews.csv', index=False, header=True, encoding='utf-8')
top10grouped.to_csv(eda_path + 'icecream_top10bot10grouped.csv', index=True, header=True, encoding='utf-8')

# %%
# iterating the top and bottom tables to generate csv gists

top_bot_list = {'top10_bj':top10_bj, 'top10_hd':top10_hd, 'top10_tl':top10_tl, 'top10_br':top10_br, 'bot10_bj':bot10_bj, 'bot10_hd':bot10_hd, 'bot10_tl':bot10_tl, 'bot10_br':bot10_br}

for top_bot_csvname, top_bot_df  in top_bot_list.items():
    csv_name = 'icecream_' + top_bot_csvname + '.csv'
    csv_path = os.path.join(eda_path, csv_name)
    top_bot_df.to_csv(csv_path, index=False, header=True, encoding='cp1252')

# %% [markdown]
# * Saving the pre-processing results

# %%
# we will use this csv file in the next project phase
pre_processed_csv_path = os.path.join(project_root, 'data', 'intermediate', 'pre-processed.csv')
df.to_csv(pre_processed_csv_path, index=False, header=True, encoding='utf-8')
